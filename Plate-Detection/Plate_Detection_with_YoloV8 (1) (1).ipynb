# %%
pip install roboflow
# Out:
# /bin/bash: /home/ardikasatria/miniconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from pylab import rcParams
from roboflow import Roboflow
rf = Roboflow(api_key="gHANp2vsdcbZgpkd2rcs")
project = rf.workspace("plate-detection-hhwwz").project("plate-text-detection")
dataset = project.version(2).download("yolov8")
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.134`, to intall it `pip install ultralytics==8.0.134`.
# ...
# Extracting Dataset Version Zip to plate-text-detection-2 in yolov8:: 100%|█████████████████████████| 1403/1403 [00:00<00:00, 11161.94it/s]

# %%
pip install matplotlib
# Out:
# /bin/bash: /home/ardikasatria/miniconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ultralytics
# Out:
# /bin/bash: /home/ardikasatria/miniconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.3/616.3 KB 16.8 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 22.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.1/282.1 KB 43.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.175 🚀 Python-3.10.12 torch-1.11.0+cu113 CUDA:0 (NVIDIA L4, 22517MiB)
# Setup complete ✅ (8 CPUs, 31.3 GB RAM, 44.5/48.3 GB disk)

# %%
pwd
# Out:
# '/home/ardikasatria'

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

# Train the model
results = model.train(data='/home/ardikasatria/plate-text-detection-2/data.yaml', epochs=150, imgsz=(640, 300))
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
result_plot = plt.imread("/home/ardikasatria/runs/detect/train7/results.png")
plt.figure(figsize=(50, 25))
plt.imshow(result_plot)
plt.show()

# %%
eval_list = ["/home/ardikasatria/runs/detect/train7/F1_curve.png", "/home/ardikasatria/runs/detect/train7/PR_curve.png", "/home/ardikasatria/runs/detect/train7/P_curve.png",
             "/home/ardikasatria/runs/detect/train7/R_curve.png", "/home/ardikasatria/runs/detect/train7/confusion_matrix.png",
             "/home/ardikasatria/runs/detect/train7/confusion_matrix_normalized.png"]

f1_curve = plt.imread(eval_list[0])
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(f1_curve)

# %%
pr_curve = plt.imread(eval_list[1])
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(pr_curve)

# %%
p_curve = plt.imread(eval_list[2])
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(p_curve)

# %%
r_curve = plt.imread(eval_list[3])
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(r_curve)

# %%
cm = plt.imread(eval_list[4])
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(cm)

# %%
cm_n = plt.imread(eval_list[5])
plt.figure(figsize=(10, 10))
plt.axis('off')
plt.imshow(cm_n)

# %%
model = YOLO('/home/ardikasatria/runs/detect/train7/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps
# Out:
# Ultralytics YOLOv8.0.175 🚀 Python-3.10.12 torch-1.11.0+cu113 CUDA:0 (NVIDIA L4, 22517MiB)
# YOLOv8n summary (fused): 168 layers, 3012863 parameters, 0 gradients
# val: Scanning /home/ardikasatria/plate-text-detection-2/valid/labels.cache... 140 images, 0 backgrounds, 0 corrupt: 100%|██████████| 140/1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [00:06<00:00,  1.49it/s]
#                    all        140       1072      0.928      0.936      0.974      0.785
#                      0        140         50      0.941       0.96      0.977      0.803
#                      1        140        158      0.981      0.978      0.992      0.704
#                      2        140         49      0.956          1      0.995      0.802
#                      3        140         35      0.963          1      0.986       0.81
#                      4        140         50      0.949       0.94      0.986      0.769
# ...

# %%
import cv2
image_test = cv2.imread("/home/ardikasatria/plate-text-detection-2/valid/images/DataTrain143_png.rf.acc8a671153d077133c1a32fa4db509c.jpg")
plt.imshow(image_test)

# %%
def prediksi(image, model, conf_thresh=0.0):
  results = model.predict(image)
  for result in results:
    boxes = result.boxes.cpu().numpy() # get boxes on cpu in numpy
    for box in boxes: # iterate boxes
      r = box.xyxy[0].astype(int) # get corner points as int
      print(r) # print boxes
      cv2.rectangle(image, r[:2], r[2:], (0,255,0), 2) # draw boxes on image
      cls = result.names[int(box.cls[0])]
      cv2.putText(image, str(cls), (r[0] + 10, r[1] - 20), cv2.FONT_HERSHEY_DUPLEX, 1, (0, 255, 255), 2)
  plt.imshow(image)

# %%
prediksi(image_test, model)
# Out:
# 0: 320x640 2 0s, 1 1, 1 4, 1 B, 1 N, 1 U, 14.4ms
# Speed: 3.5ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# [216  67 252 193]
# [250  65 287 189]
# [358  59 396 186]
# [178  73 215 197]
# [ 59  81  99 210]
# [150  75 175 200]
# [397  56 435 189]

# %%
def prediksi_(image, model, conf_thresh=0.0):
  results = model.predict(image)
  clas = []
  boxx = []
  for result in results:
    boxes = result.boxes.cpu().numpy()
    for box in boxes:
      r = box.xyxy[0].astype(int) 
      cls = result.names[int(box.cls[0])]
      clas.append(cls)
      boxx.append(r[0])
  boxx_sort = sorted(boxx)
  sorted_clas = [x for _, x in sorted(zip(boxx, clas))]
  kelas = ''.join(sorted_clas)
  plt.title("Prediksi: "+kelas)
  plt.imshow(image)
  return kelas

# %%
prediksi_(image_test, model)
# Out:
# 0: 320x640 2 0s, 1 1, 1 4, 1 B, 1 N, 1 U, 11.5ms
# Speed: 3.1ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 'B1040UN'
